# %%
#Importing all neccessary libraries.
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time

# %%
#Connect to the API.
client_id = "paste your client_id here"
client_secret = "paste your client_secret here"

# %%
client_credentials_manager = SpotifyClientCredentials("paste your client_id here","paste your client_secret here" )
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# *In the code above, replace the Client ID and Client Secret variables with your own and make sure they are inside quotes.*

# %%
#Retrieve id's for each track.
def getTrackIDs(user, playlist_id):
    ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        ids.append(track['id'])
    return ids

ids = getTrackIDs('saima', '3Mp44OXnA3QOmjyeJzTvXD')

# %%
print(len(ids))
print(ids)
# Out:
# 100
# ['4eHbdreAnSOrDDsFfc4Fpm', '6cARFkZxx2JR3JlvDzeLZc', '1rO1CMRf4RrnkqRlnKvoqs', '3zr2s3o2Ye1j6t0ZMdoUYi', '3VN8gOBCgbQqsGQsd1Opve', '05fHQeRbCSjKVS6z0WbQKJ', '6mORGLOz79w6VsCRLWYYuK', '4rfh0qEv1HdKRXWiRXfzWF', '7F1yVPuJ4xRdrDvf8OL0HF', '2JoZzpdeP2G6Csfdq5aLXP', '0fIOacVe000P5pNhaKQlQw', '6pgIjoj3BRXRCXRCMPjwvv', '5KawlOMHjWeUjQtnuRs22c', '3dQ71J2HPHXpPqJ0tQdDHR', '62z2Su8BBGvR50aOvdjPzW', '3dnc2Ex0GN8kYpsT44C09D', '24Yi9hE78yPEbZ4kxyoXAI', '364dI1bYnvamSnBJ8JcNzN', '6T689Jvh5KrSXyaPtUWZtQ', '33z5crv3IO5U2BOi8xod92', '4nK5YrxbMGZstTLbvj6Gxw', '7k4t7uLgtOxPwTpFmtJNTY', '4T652DlATVHe0jdLKaN3Bw', '0bMbDctzMmTyK2j74j3nF3', '0bmQ5H9mHFzRnJ4ZntylFg', '3QNG9RhD93ypeMp3DUmkaO', '62aP9fBQKYKxi7PDXwcUAS', '1FgPyHX7HruKDL4Tx4MeZB', '4IqcDJPzDL8Hq8KwAX4jUE', '3QXiUbsLYt06h5aDa1PQ30', '68UU9oaQtMDnh6PRlW842H', '2Fxmhks0bxGSBdJ92vM42m', '0u2P5u6lvoDfwTYjAADbn4', '3ZCTVFBt2Brf31RLEnCkWJ', '00yinrzqPZKA2vbnwnn3hS', '0qvzXomUDJVaUboy2wMfiS', '5EcpuCZ75oXmU5j0Hqoyys', '7gd01LMH2gBcoDngSt8sq9', '78qd8dvwea0Gosb6Fe6j3k', '11VApNQCWLJdzxWrlmwzUa', '6aTtl40Or1Mgx2pjcP1T9L', '2ndF5ctDJrYK3eJhRbp1jO', '04NRBYtE0lQRy8XcrIxnBd', '64rL48E6xWMIXdpcFDEiB8', '40BHvbyw4UeadzkzaVpcbD', '3xr8COed4nPPn6XWZ0iCGr', '4qto2kJITIHyE086P4WtkU', '3Dv1eDb0MEgF93GpLXlucZ', '2b8fOow8UzyDFAE27YhOZM', '5iFwAOB2TFkPJk8sMlxP8g', '0yIywEquxORnu1dR0WYsdN', '0171XsIM2xyeXRr6wsugEI', '6DNtNfH8hXkqOX1sjqmI7p', '0pwYLVXVknPSGUQb39cePC', '3A7qX2QjDlPnazUsRk5y0M', '190jyVPHYjAqEaOGmMzdyk', '5GYbkDveRD2I8M5ZJ14hWn', '09mhA1SJjMHniZPF4Hcihn', '6epn3r7S14KUqlReYr77hA', '6eDApnV9Jdb1nYahOlbbUh', '6dtWKqqdveI3YvdYJQKWWn', '3e9HZxeyfWwjeyPAMmWSSQ', '3zHq9ouUJQFQRf3cm1rRLu', '27tNWlhdAryQY04Gb2ZhUI', '07nH4ifBxUB4lZcsf44Brn', '3U4isOIWM3VvDubwSI3y7a', '6FZDfxM3a3UCqtzo5pxSLZ', '2qT1uLXPVPzGgFOx4jtEuo', '2xJCMIJfcNYDc5iR0sAm2O', '2BgEsaKNfHUdlh97KmvFyo', '6RtPijgfPKROxEzTHNRiDp', '1rfofaqEpACxVEHIZBJe6W', '4B0JvthVoAAuygILe3n4Bs', '6v3KW9xbzN5yKLt9YKDYA2', '1wjzFQodRWrPcQ0AnYnvQ9', '3WefHNGtjexZvi66ZEx9u4', '6ATgDc6e4sPn84hvJsAmPt', '54l9GJGQ1UCFKe2tzt1Vxt', '7COXchtUOMd6uIT6HvmRaI', '0d2iYfpKoM0QCKvcLCkBao', '5HwnezK198pJCEj1l2Adjy', '3whrwq4DtvucphBPUogRuJ', '6l0Ky2PycJV1Bz88kFeVGL', '4dH8EfwDxGjzj0358d5Tvw', '1XGmzt0PVuFgQYYnV2It7A', '0wt9RjddODlWDetpuaXfRK', '466s1BacUmiRdR3ISvNjyx', '4eumFsTnduH3zRfaASoAPs', '0fonaf88IEDQM309zmU80L', '1cdzfFjEbUbgTm5nv3FgXR', '2VhPOtIQw2UpQmRVevdviU', '4jPkb4FWzVP7NKeIMMSKF7', '3BJLJsOOHyaRQaSZJGxeDE', '4JJbnMA73TiInSEaSD2NtI', '7eS959IbSi81CQ5kSB64HT', '4FK4RZ54LKzxwVBxcZ8NsE', '57pP1na1daT3zVtQzoLCO7', '0sGPJOpsQs7K2OwxSPMmxf', '49dApkMoBJGB4NlyjTdt4s', '3QzKOkJx93qT95MpEYLYOD']

# %%
#Create a function used to grab all track info from IDs.
def getTrackFeatures(id):
  meta = sp.track(id)
  features = sp.audio_features(id)

  # meta
  name = meta['name']
  album = meta['album']['name']
  artist = meta['album']['artists'][0]['name']
  release_date = meta['album']['release_date']
  length = meta['duration_ms']
  popularity = meta['popularity']

  # features
  acousticness = features[0]['acousticness']
  danceability = features[0]['danceability']
  energy = features[0]['energy']
  instrumentalness = features[0]['instrumentalness']
  liveness = features[0]['liveness']
  loudness = features[0]['loudness']
  speechiness = features[0]['speechiness']
  tempo = features[0]['tempo']
  time_signature = features[0]['time_signature']

  track = [name, album, artist, release_date, length, popularity, danceability, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
  return track

# %%
# loop over track ids 
tracks = []
for i in range(len(ids)):
  time.sleep(.5)
  track = getTrackFeatures(ids[i])
  tracks.append(track)

# create dataset
df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
df.to_csv("spotify.csv", sep = ',')

# %%
data=pd.read_csv("spotify.csv")

# %%
data
# Out:
#     Unnamed: 0                       name  \
# 0            0     I Will Always Love You
# 1            1  Love of the Common People
# 2            2         Because I Love You
# 3            3              Song For Zula
# 4            4              Song for Zula
# ..         ...                        ...
# 95          95               I Don't Care
# 96          96                  Sometimes
# 97          97                   Everyday
# 98          98            Leave Me Lonely
# 99          99                     Greedy
#
#                                          album           artist release_date  \
# 0    The Bodyguard - Original Soundtrack Album  Whitney Houston   1992-11-17
# 1   From Time To Time - The Singles Collection       Paul Young   1991-09-07
# 2           The Hits Of Shakin' Stevens Vol II  Shakin' Stevens   1997-01-01
# 3            Muchacho De Lujo (Deluxe Edition)   Phosphorescent   2013-10-29
# 4                               Built to Break     Ronnie Fauss   2014-11-04
# ..                                         ...              ...          ...
# 95                             Dangerous Woman    Ariana Grande   2016-05-20
# 96                             Dangerous Woman    Ariana Grande   2016-05-20
# 97                             Dangerous Woman    Ariana Grande   2016-05-20
# 98                             Dangerous Woman    Ariana Grande   2016-05-20
# 99                             Dangerous Woman    Ariana Grande   2016-05-20
#
#     length  popularity  danceability  acousticness  danceability.1  energy  \
# 0   271093          77         0.306        0.8440           0.306   0.214
# 1   220733          56         0.744        0.0883           0.744   0.609
# 2   197600          40         0.587        0.2440           0.587   0.343
# 3   370200          59         0.492        0.7290           0.492   0.626
# 4   296840          31         0.506        0.7340           0.506   0.422
# ..     ...         ...           ...           ...             ...     ...
# 95  178026          24         0.585        0.7730           0.585   0.401
# 96  226666          28         0.397        0.0907           0.397   0.666
# 97  194840          38         0.630        0.0170           0.630   0.721
# 98  229680          27         0.445        0.5990           0.445   0.446
# 99  214906          39         0.619        0.0323           0.619   0.705
#
#     instrumentalness  liveness  loudness  speechiness    tempo  time_signature
# 0           0.000005    0.0839   -12.518       0.0356   66.980               4
# 1           0.000000    0.0599   -11.202       0.0758   90.723               4
# 2           0.000120    0.1180   -12.891       0.0255  102.070               4
# 3           0.533000    0.0509    -8.260       0.0349   86.016               4
# 4           0.000013    0.0737    -6.931       0.0246  142.009               4
# ..               ...       ...       ...          ...      ...             ...
# 95          0.000000    0.1530    -8.319       0.0412  111.956               4
# 96          0.000000    0.3440    -5.383       0.2480   77.915               4
# 97          0.000000    0.1890    -4.510       0.0521  130.974               4
# 98          0.000022    0.3390    -7.468       0.0312   90.927               3
# 99          0.000000    0.0919    -5.335       0.0990  109.975               4
#
# [100 rows x 17 columns]
